# %%
import os
import shutil
import random
from tqdm import tqdm

# %%
RAW_DIR = "../data/rraw/tomato"
PROCESSED_DIR = "../data/processed"

TRAIN_RATIO = 0.7
VAL_RATIO = 0.15
TEST_RATIO = 0.15

random.seed(42)

# %%
classes = os.listdir(RAW_DIR)
print("Found classes:", classes)
# Out:
# Found classes: ['Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___healthy', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_mosaic_virus', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus']

# %%
for cls in classes:
    cls_path = os.path.join(RAW_DIR, cls)
    images = os.listdir(cls_path)
    random.shuffle(images)

    total = len(images)
    train_end = int(TRAIN_RATIO * total)
    val_end = train_end + int(VAL_RATIO * total)

    splits = {
        "train": images[:train_end],
        "val": images[train_end:val_end],
        "test": images[val_end:]
    }

    for split, split_images in splits.items():
        split_cls_dir = os.path.join(PROCESSED_DIR, split, cls)
        os.makedirs(split_cls_dir, exist_ok=True)

        for img in tqdm(split_images, desc=f"{cls} → {split}"):
            src = os.path.join(cls_path, img)
            dst = os.path.join(split_cls_dir, img)
            shutil.copy(src, dst)
# Out:
# Tomato___Bacterial_spot → train: 100%|██████████| 1191/1191 [00:33<00:00, 35.74it/s]
# Tomato___Bacterial_spot → val: 100%|██████████| 255/255 [00:06<00:00, 37.16it/s]
# Tomato___Bacterial_spot → test: 100%|██████████| 256/256 [00:06<00:00, 37.18it/s]
# Tomato___Early_blight → train: 100%|██████████| 560/560 [00:15<00:00, 36.67it/s]
# Tomato___Early_blight → val: 100%|██████████| 120/120 [00:03<00:00, 34.17it/s]
# Tomato___Early_blight → test: 100%|██████████| 120/120 [00:03<00:00, 37.88it/s]
# Tomato___healthy → train: 100%|██████████| 891/891 [00:23<00:00, 37.35it/s]
# Tomato___healthy → val: 100%|██████████| 190/190 [00:05<00:00, 37.37it/s]
# Tomato___healthy → test: 100%|██████████| 192/192 [00:05<00:00, 37.71it/s]
# Tomato___Late_blight → train: 100%|██████████| 1068/1068 [00:28<00:00, 37.68it/s]
# Tomato___Late_blight → val: 100%|██████████| 229/229 [00:06<00:00, 35.59it/s]
# Tomato___Late_blight → test: 100%|██████████| 230/230 [00:06<00:00, 35.45it/s]
# Tomato___Leaf_Mold → train: 100%|██████████| 532/532 [00:14<00:00, 36.54it/s]
# Tomato___Leaf_Mold → val: 100%|██████████| 114/114 [00:03<00:00, 35.93it/s]
# Tomato___Leaf_Mold → test: 100%|██████████| 115/115 [00:03<00:00, 34.80it/s]
# Tomato___Septoria_leaf_spot → train: 100%|██████████| 991/991 [00:27<00:00, 36.23it/s]
# Tomato___Septoria_leaf_spot → val: 100%|██████████| 212/212 [00:05<00:00, 37.47it/s]
# Tomato___Septoria_leaf_spot → test: 100%|██████████| 214/214 [00:06<00:00, 35.58it/s]
# Tomato___Spider_mites Two-spotted_spider_mite → train: 100%|██████████| 938/938 [00:25<00:00, 36.70it/s]
# Tomato___Spider_mites Two-spotted_spider_mite → val: 100%|██████████| 201/201 [00:05<00:00, 36.66it/s]
# Tomato___Spider_mites Two-spotted_spider_mite → test: 100%|██████████| 202/202 [00:05<00:00, 34.78it/s]
# Tomato___Target_Spot → train: 100%|██████████| 786/786 [00:21<00:00, 37.26it/s]
# Tomato___Target_Spot → val: 100%|██████████| 168/168 [00:04<00:00, 36.63it/s]
# Tomato___Target_Spot → test: 100%|██████████| 169/169 [00:04<00:00, 36.92it/s]
# Tomato___Tomato_mosaic_virus → train: 100%|██████████| 209/209 [00:05<00:00, 37.48it/s]
# Tomato___Tomato_mosaic_virus → val: 100%|██████████| 44/44 [00:01<00:00, 37.71it/s]
# Tomato___Tomato_mosaic_virus → test: 100%|██████████| 46/46 [00:01<00:00, 37.52it/s]
# Tomato___Tomato_Yellow_Leaf_Curl_Virus → train: 100%|██████████| 3000/3000 [01:22<00:00, 36.54it/s]
# Tomato___Tomato_Yellow_Leaf_Curl_Virus → val: 100%|██████████| 642/642 [00:17<00:00, 36.82it/s]
# Tomato___Tomato_Yellow_Leaf_Curl_Virus → test: 100%|██████████| 644/644 [00:17<00:00, 37.25it/s]
